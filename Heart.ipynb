# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Disease_symptom_and_patient_profile_dataset.csv')

# %%
df.head()
# Out:
#        Disease Fever Cough Fatigue Difficulty Breathing  Age  Gender  \
# 0    Influenza   Yes    No     Yes                  Yes   19  Female
# 1  Common Cold    No   Yes     Yes                   No   25  Female
# 2       Eczema    No   Yes     Yes                   No   25  Female
# 3       Asthma   Yes   Yes      No                  Yes   25    Male
# 4       Asthma   Yes   Yes      No                  Yes   25    Male
#
#   Blood Pressure Cholesterol Level Outcome Variable
# 0            Low            Normal         Positive
# 1         Normal            Normal         Negative
# 2         Normal            Normal         Negative
# 3         Normal            Normal         Positive
# 4         Normal            Normal         Positive

# %%
df.shape
# Out:
# (349, 10)

# %%
Disease =list( df['Disease'].value_counts().keys())
No_of_counts = list( df['Disease'].value_counts().values)

# %%
# bar chart used when 1) value is catgorical on x axis and 1) value is numerical on y axis
plt.figure(figsize=(10, 6))    # figsize for weith and height
plt.bar( Disease, No_of_counts, color = 'green' , ec = 'r', lw = 2 , ls='dotted' , width= 0.6)   # ec -> edge color  # lw-> line width # ls -> line style
plt.xlabel('Disease Name')
plt.ylabel('No_of_counts')
plt.title("No of Disease")
# for remove overlapping
plt.xticks(rotation = 75)
plt.show()

# %%
df['Disease'].nunique()
# Out:
# 116

# %%
ls=[]
ls=df['Disease'].unique()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349 entries, 0 to 348
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Disease               349 non-null    object
#  1   Fever                 349 non-null    object
#  2   Cough                 349 non-null    object
#  3   Fatigue               349 non-null    object
#  4   Difficulty Breathing  349 non-null    object
#  5   Age                   349 non-null    int64
#  6   Gender                349 non-null    object
#  7   Blood Pressure        349 non-null    object
#  8   Cholesterol Level     349 non-null    object
#  9   Outcome Variable      349 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 27.4+ KB

# %%
df['Blood Pressure'].value_counts()
# Out:
# Blood Pressure
# High      167
# Normal    164
# Low        18
# Name: count, dtype: int64

# %%
Blood_Pressure = list(df['Blood Pressure'].value_counts().keys())
value_counts = list(df['Blood Pressure'].value_counts().values)

import numpy as np
np.array(value_counts)
# Out:
# array([167, 164,  18], dtype=int64)

# %%
df['Cholesterol Level'].value_counts()
# Out:
# Cholesterol Level
# High      166
# Normal    149
# Low        34
# Name: count, dtype: int64

# %%
df['Cough'].value_counts()
# Out:
# Cough
# No     182
# Yes    167
# Name: count, dtype: int64

# %%
df['Difficulty Breathing'].value_counts()
# Out:
# Difficulty Breathing
# No     261
# Yes     88
# Name: count, dtype: int64

# %%
df['Disease'].value_counts()
# Out:
# Disease
# Asthma               23
# Stroke               16
# Osteoporosis         14
# Diabetes             10
# Hypertension         10
#                      ..
# Schizophrenia         1
# Gout                  1
# Testicular Cancer     1
# Tonsillitis           1
# Williams Syndrome     1
# Name: count, Length: 116, dtype: int64

# %%
df['Disease'].unique()
# Out:
# array(['Influenza', 'Common Cold', 'Eczema', 'Asthma', 'Hyperthyroidism',
#        'Allergic Rhinitis', 'Anxiety Disorders', 'Diabetes',
#        'Gastroenteritis', 'Pancreatitis', 'Rheumatoid Arthritis',
#        'Depression', 'Liver Cancer', 'Stroke', 'Urinary Tract Infection',
#        'Dengue Fever', 'Hepatitis', 'Kidney Cancer', 'Migraine',
#        'Muscular Dystrophy', 'Sinusitis', 'Ulcerative Colitis',
#        'Bipolar Disorder', 'Bronchitis', 'Cerebral Palsy',
#        'Colorectal Cancer', 'Hypertensive Heart Disease',
#        'Multiple Sclerosis', 'Myocardial Infarction (Heart...',
#        'Urinary Tract Infection (UTI)', 'Osteoporosis', 'Pneumonia',
#        'Atherosclerosis', 'Chronic Obstructive Pulmonary...', 'Epilepsy',
#        'Hypertension', 'Obsessive-Compulsive Disorde...', 'Psoriasis',
#        'Rubella', 'Cirrhosis', 'Conjunctivitis (Pink Eye)',
#        'Liver Disease', 'Malaria', 'Spina Bifida', 'Kidney Disease',
# ...

# %%
unique_diseases = df['Disease'].unique()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

df['Disease'] = label_encoder.fit_transform(df['Disease'])

# %%
disease_names = df['Disease'].unique()
disease_names = label_encoder.inverse_transform(disease_names)

# %%
df.head()
# Out:
#    Disease  Fever  Cough  Fatigue  Difficulty Breathing  Age  Gender  \
# 0       56      1      0        1                     1   19       1
# 1       24      0      1        1                     0   25       1
# 2       37      0      1        1                     0   25       1
# 3        6      1      1        0                     1   25       0
# 4        6      1      1        0                     1   25       0
#
#    Blood Pressure  Cholesterol Level  Outcome Variable
# 0             0.0                  1                 0
# 1             1.0                  1                 1
# 2             1.0                  1                 1
# 3             1.0                  1                 0
# 4             1.0                  1                 0

# %%
df['Fatigue'].value_counts()
# Out:
# Fatigue
# Yes    242
# No     107
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    176
# Male      173
# Name: count, dtype: int64

# %%
df['Fatigue'].value_counts()
# Out:
# Fatigue
# Yes    242
# No     107
# Name: count, dtype: int64

# %%
df['Outcome Variable'].value_counts()
# Out:
# Outcome Variable
# Positive    186
# Negative    163
# Name: count, dtype: int64

# %%
df['Outcome Variable'].value_counts()
# Out:
# Outcome Variable
# Positive    186
# Negative    163
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Disease', 'Fever', 'Cough', 'Fatigue', 'Difficulty Breathing', 'Age',
#        'Gender', 'Blood Pressure', 'Cholesterol Level', 'Outcome Variable'],
#       dtype='object')

# %%
fever_dict = {'Yes':1 , 'No':0} 

df['Fever'] = df['Fever'].map(fever_dict)

# %%
cough_dict = {'Yes':1 , 'No':0} 

df['Cough'] = df['Cough'].map(cough_dict)

# %%
Gender_dict = {'Female':1 , 'Male':0} 

df['Gender'] = df['Gender'].map(Gender_dict)

# %%
Fatigue_dict = {'Yes':1 , 'No':0} 

df['Fatigue'] = df['Fatigue'].map(Fatigue_dict)

# %%
Difficulty_Breathing_dict = {'Yes':1 , 'No':0} 

df['Difficulty Breathing'] = df['Difficulty Breathing'].map(Difficulty_Breathing_dict)

# %%
Blood_Pressure_dict = {'Normal':1 , 'Low':0} 

df['Blood Pressure'] = df['Blood Pressure'].map(Blood_Pressure_dict)

# %%
Cholesterol_Level_dict = {'Low':0 , 'Normal':1 , 'High':2} 	
df['Cholesterol Level'] =df['Cholesterol Level'].map(Cholesterol_Level_dict)

# %%
df['Outcome Variable'].unique()
# Out:
# array(['Positive', 'Negative'], dtype=object)

# %%
Outcome_Variable_dict = {'Positive':0 , 'Negative':1 } 	
df['Outcome Variable'] =df['Outcome Variable'].map(Outcome_Variable_dict)

# %%
df.head()
# Out:
#        Disease  Fever  Cough  Fatigue  Difficulty Breathing  Age  Gender  \
# 0    Influenza      1      0        1                     1   19       1
# 1  Common Cold      0      1        1                     0   25       1
# 2       Eczema      0      1        1                     0   25       1
# 3       Asthma      1      1        0                     1   25       0
# 4       Asthma      1      1        0                     1   25       0
#
#    Blood Pressure  Cholesterol Level  Outcome Variable
# 0             0.0                  1                 0
# 1             1.0                  1                 1
# 2             1.0                  1                 1
# 3             1.0                  1                 0
# 4             1.0                  1                 0

# %%
X = df.drop('Outcome Variable', axis=1)
y = df['Outcome Variable']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
model = RandomForestClassifier()

# %%
print(model.score(X,y))
# Out:
# 1.0

# %%
import joblib , os

# %%
joblib.dump(model, './models/randomforest.lb')
# Out:
# ['./models/randomforest.lb']
